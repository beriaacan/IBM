# %% [markdown]
# <a href="https://colab.research.google.com/github/beriaacan/IBM/blob/main/python4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
x= {"name":["beria", "refia", "hamza","ayse", "ergun"], "age": ["23", "20", "11","45","53"],"birth date" : ["2000", "2003", "2012","1978" ,"1970"],"eye colour" : ["green", "dark", "green","brown","green"]
    ,"hair colour" : ["brown", "black", "blond","black","gray"]}
df=pd.DataFrame(x)
df
# Out:
#     name age birth date eye colour hair colour
# 0  beria  23       2000      green       brown
# 1  refia  20       2003       dark       black
# 2  hamza  11       2012      green       blond
# 3   ayse  45       1978      brown       black
# 4  ergun  53       1970      green        gray

# %%
x = df["name"]
x
#type(x)
# Out:
# 0    beria
# 1    refia
# 2    hamza
# 3     ayse
# 4    ergun
# Name: name, dtype: object

# %%
x=df[["name"]]
x
#type(x)
# Out:
#     name
# 0  beria
# 1  refia
# 2  hamza
# 3   ayse
# 4  ergun

# %%
z = df[["name", "age"]]
z
# Out:
#     name age
# 0  beria  23
# 1  refia  20
# 2  hamza  11
# 3   ayse  45
# 4  ergun  53

# %%
df.iloc[0, 0]
# Out:
# 'beria'

# %%
df.loc[0, 'name']
# Out:
# 'beria'

# %%
df.iloc[0:2, 0:3]
# Out:
#     name age birth date
# 0  beria  23       2000
# 1  refia  20       2003

# %%
df2=df
df2=df2.set_index("name")

# %%
#To display the first 5 rows of new dataframe
df2.head()
# Out:
#       age birth date eye colour hair colour
# name
# beria  23       2000      green       brown
# refia  20       2003       dark       black
# hamza  11       2012      green       blond
# ayse   45       1978      brown       black
# ergun  53       1970      green        gray
